# %% [markdown]
# # Week 1 - Battle of the Neighborhoods
# NB: please note, this notebook contains multiple, so please scroll to find desired section.

# %% [markdown]
# # 1. Introduction / Business Problem
# Sydney is the largest city in Australia with a population of over 4.5 million people. Naturally both variation and similarities would exist across the numerous suburbs.
#
# For the target audience of existing business owners or aspiring new ones, knowing ones market is important in order to inform decision making and investment choices.
#
# This Notebook will explore the suburbs of Sydney, Australia to discover interesting relationships between the suburbs. These suburbs will be segmented and clustered in order to determine certain characteristics about Sydney.
#
# - What is the most popular venue type?
# - How similar are the various suburbs of Sydney to each other?
# - Which suburbs are missing certain (popular) venues?
# - Where might be the best place to open a new venue?
# - What venue might this be?
#
# These questions will be of interest for both existing venue owners in Sydney to understand the markets they operate in, as well as for new entrants seeking to open a venue.
#
# Establishing a certain venue in an area already saturated with those venues could be a critical business mistake, and having this knowledge prior to investment could create successful outcomes for stakeholders. To the contrary, an investment could be worthwhile if a business owner knows that her/his particular method of operation is superior to others, and hence knowing which areas are saturated with different types of venues could inform decision making, as it would be indicative of customer preferences in those areas.
#
# Hence, this problem would be of key interest for business owners in a multitude of ways.

# %% [markdown]
# # 2. Data
# The data that will be used to solve for this problem will primarily be **FourSquare's location data**.
#
# In addition, **Australian suburb and postcode data** will be required, along with latitude and longitude data for the correpsonding suburbs.
#
# Longitude and Latitude data will be created via Python's geospatial packages using suburb addresses.
#
# The data will be used to solve the data by mapping the most common venues to a given suburb and aggregating these results across all of Sydney.
#
# In the future, additional information could be brought in, such as housing / commercial property prices, commercial / residential vacancy rates or building approvals data to further gauge where best to establish a specific type of venue would be.
#
# The **postal data looks as follows:**

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#         Suburb  Postcode
# 0       Ultimo      2007
# 1  Chippendale      2008
# 2      Pyrmont      2009
# 3  Surry Hills      2010
# 4  Kings Cross      2011

# %% [markdown]
# The postal data after a geospatial overlay of **latitude and longitude** values looks as follows:

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#   Neighborhood   Latitude   Longitude
# 0       Ultimo -33.879473  151.198435
# 1  Chippendale -33.886329  151.199821
# 2      Pyrmont -33.869214  151.192363
# 3  Surry Hills -33.884512  151.210030
# 4  Kings Cross -33.874601  151.222423

# %% [markdown]
# And lastly, the postal data combined with **Foursquare's location data** looks as follows:

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0       Ultimo             -33.879473              151.198435
# 1       Ultimo             -33.879473              151.198435
# 2       Ultimo             -33.879473              151.198435
# 3       Ultimo             -33.879473              151.198435
# 4       Ultimo             -33.879473              151.198435
#
#                                Venue  Venue Latitude  Venue Longitude  \
# 0  Museum of Applied Arts & Sciences      -33.878985       151.199555
# 1                    The Q on Harris      -33.879394       151.199455
# 2          Ian Thorpe Aquatic Centre      -33.877254       151.198805
# 3                  Powerhouse Museum      -33.878592       151.199512
# 4            Edition Coffee Roasters      -33.878485       151.201190
#
#    Venue Category
# 0          Museum
# 1     Coffee Shop
# 2            Pool
# 3  Science Museum
# 4            Café

# %% [markdown]
# After ingesting the postal and foursquare location data, the top 10 most common venues were determined for all the suburbs of Sydney

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#    Cluster Labels Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0               1   Alexandria                  Café      Basketball Court
# 1               1    Annandale                  Café         Grocery Store
# 2               0    Arncliffe         Grocery Store              Platform
# 3               1     Artarmon                  Café   Japanese Restaurant
# 4               0     Ashfield    Chinese Restaurant   Japanese Restaurant
#
#        3rd Most Common Venue      4th Most Common Venue 5th Most Common Venue  \
# 0  Middle Eastern Restaurant         Italian Restaurant                   Bar
# 1      Australian Restaurant        Fried Chicken Joint     Fish & Chips Shop
# 2               Dessert Shop  Middle Eastern Restaurant              Pharmacy
# 3                       Park            Thai Restaurant     Korean Restaurant
# 4        Shanghai Restaurant          Electronics Store   Dumpling Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0             Wine Shop           Flower Shop     Fish & Chips Shop
# 1          Liquor Store        Farmers Market                   Pub
# 2          Intersection          Outlet Store                  Park
# 3           Coffee Shop      Sushi Restaurant      Ramen Restaurant
# 4          Liquor Store            Restaurant           Supermarket
#
#   9th Most Common Venue 10th Most Common Venue
# 0           Fish Market            Flea Market
# 1                   Bar                 Bakery
# 2           Fish Market   Fast Food Restaurant
# 3         Grocery Store                 Bakery
# 4     Korean Restaurant       Malay Restaurant

# %% [markdown]
# To this location data, cluster labels were added, as well as latitude and longitude values
#
# One issue encountered was that the Cluster Labels were a float data type, and hence could not be interpretted by the Folium mapping package.
#
# To solve for this issue, the labels were converted to integers in order to make them ready to be mapped across Sydney for some data visualisation

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#   Neighborhood   Latitude   Longitude  Cluster Labels 1st Most Common Venue  \
# 0       Ultimo -33.879473  151.198435               1                  Café
# 1  Chippendale -33.886329  151.199821               1                  Café
# 2      Pyrmont -33.869214  151.192363               0                   Bar
# 3  Surry Hills -33.884512  151.210030               1                  Café
# 4  Kings Cross -33.874601  151.222423               1                  Café
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0           Coffee Shop      Malay Restaurant                   Pub
# 1                   Bar                 Hotel           Art Gallery
# 2    Seafood Restaurant   Japanese Restaurant    Italian Restaurant
# 3           Coffee Shop                   Pub           Yoga Studio
# 4    Italian Restaurant     Indian Restaurant                Lounge
#
#    5th Most Common Venue 6th Most Common Venue    7th Most Common Venue  \
# 0       Asian Restaurant               Theater                     Pool
# 1            Yoga Studio              Wine Bar         Malay Restaurant
# 2                   Café                   Pub              Fish Market
# 3    Japanese Restaurant          Cocktail Bar         Ramen Restaurant
# 4  Australian Restaurant             Juice Bar  Fruit & Vegetable Store
#
#   8th Most Common Venue  9th Most Common Venue 10th Most Common Venue
# 0   Dumpling Restaurant  Australian Restaurant                 Lounge
# 1   Fried Chicken Joint    Dumpling Restaurant           Dessert Shop
# 2           Coffee Shop             Restaurant       Malay Restaurant
# 3        Sandwich Place     Mexican Restaurant         Breakfast Spot
# 4             Nightclub     Chinese Restaurant    Rental Car Location

# %% [markdown]
# Below is a map of Sydney with the clusters plotted and coloured depending on which cluster they belong to

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# See below for a sample of the 4 clusters found around Sydney based on venue location data.

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#       Neighborhood  1st Most Common Venue 2nd Most Common Venue  \
# 2          Pyrmont                    Bar    Seafood Restaurant
# 10          Mascot        Thai Restaurant                Bakery
# 12  Bondi Junction                   Café          Burger Joint
# 16           Bondi  Australian Restaurant                  Park
# 17       Edgecliff            Supermarket   Japanese Restaurant
#
#    3rd Most Common Venue      4th Most Common Venue 5th Most Common Venue  \
# 2    Japanese Restaurant         Italian Restaurant                  Café
# 10                  Café  Middle Eastern Restaurant           Pizza Place
# 12    Mexican Restaurant           Sushi Restaurant          Noodle House
# 16       Thai Restaurant                       Café           Pizza Place
# 17        Tennis Stadium                     Bakery                   Gym
#
#    6th Most Common Venue  7th Most Common Venue  8th Most Common Venue  \
# 2                    Pub            Fish Market            Coffee Shop
# 10            Playground  Indonesian Restaurant                   Park
# 12   Japanese Restaurant     Italian Restaurant             Steakhouse
# 16         Grocery Store          Deli / Bodega   Brazilian Restaurant
# 17                   Pub                   Café  Australian Restaurant
#
#         9th Most Common Venue 10th Most Common Venue
# 2                  Restaurant       Malay Restaurant
# 10         Italian Restaurant          Souvlaki Shop
# 12                  Bookstore         Sandwich Place
# 16  Middle Eastern Restaurant    American Restaurant
# 17              Train Station         Sandwich Place

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#   Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0       Ultimo                  Café           Coffee Shop
# 1  Chippendale                  Café                   Bar
# 3  Surry Hills                  Café           Coffee Shop
# 4  Kings Cross                  Café    Italian Restaurant
# 5   Alexandria                  Café      Basketball Court
#
#        3rd Most Common Venue 4th Most Common Venue  5th Most Common Venue  \
# 0           Malay Restaurant                   Pub       Asian Restaurant
# 1                      Hotel           Art Gallery            Yoga Studio
# 3                        Pub           Yoga Studio    Japanese Restaurant
# 4          Indian Restaurant                Lounge  Australian Restaurant
# 5  Middle Eastern Restaurant    Italian Restaurant                    Bar
#
#   6th Most Common Venue    7th Most Common Venue 8th Most Common Venue  \
# 0               Theater                     Pool   Dumpling Restaurant
# 1              Wine Bar         Malay Restaurant   Fried Chicken Joint
# 3          Cocktail Bar         Ramen Restaurant        Sandwich Place
# 4             Juice Bar  Fruit & Vegetable Store             Nightclub
# 5             Wine Shop              Flower Shop     Fish & Chips Shop
#
#    9th Most Common Venue 10th Most Common Venue
# 0  Australian Restaurant                 Lounge
# 1    Dumpling Restaurant           Dessert Shop
# 3     Mexican Restaurant         Breakfast Spot
# 4     Chinese Restaurant    Rental Car Location
# 5            Fish Market            Flea Market

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#        Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 61   Berowra Waters    Seafood Restaurant         Boat or Ferry
# 120       Northmead    Seafood Restaurant         Bowling Green
# 196    Quakers Hill        Baseball Field             Wine Shop
#
#     3rd Most Common Venue  4th Most Common Venue 5th Most Common Venue  \
# 61        Harbor / Marina  Australian Restaurant     Fish & Chips Shop
# 120       Badminton Court         Baseball Field     French Restaurant
# 196        Farmers Market    Fried Chicken Joint     French Restaurant
#
#     6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 61            Fish Market           Flea Market           Flower Shop
# 120            Food Truck          Food Service            Food Court
# 196            Food Truck          Food Service            Food Court
#
#     9th Most Common Venue 10th Most Common Venue
# 61              Wine Shop   Fast Food Restaurant
# 120  Fast Food Restaurant      Food & Drink Shop
# 196     Food & Drink Shop            Flower Shop

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#     Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 77    Warriewood      Business Service             Wine Shop
# 105  Strathfield      Business Service             Wine Shop
#
#     3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 77         Farmers Market   Fried Chicken Joint     French Restaurant
# 105        Farmers Market   Fried Chicken Joint     French Restaurant
#
#     6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 77             Food Truck          Food Service            Food Court
# 105            Food Truck          Food Service            Food Court
#
#     9th Most Common Venue 10th Most Common Venue
# 77      Food & Drink Shop            Flower Shop
# 105     Food & Drink Shop            Flower Shop

# %% [markdown]
# # ****************************************************
# # Code used

# %% [markdown]
# # Import Libraries

# %%
# Import libraries 
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/DSX-Python35
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     certifi-2018.8.24          |        py35_1001         139 KB  conda-forge
#     altair-2.2.2               |           py35_1         462 KB  conda-forge
#     openssl-1.0.2r             |       h14c3975_0         3.1 MB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     branca-0.3.1               |             py_0          25 KB  conda-forge
#     ca-certificates-2019.3.9   |       hecc5488_0         146 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.0 MB
#
# The following NEW packages will be INSTALLED:
#
#     altair:          2.2.2-py35_1      conda-forge
#     branca:          0.3.1-py_0        conda-forge
#     folium:          0.5.0-py_0        conda-forge
#     vincent:         0.4.4-py_1        conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.1.23-0                   --> 2019.3.9-hecc5488_0 conda-forge
#     certifi:         2018.8.24-py35_1              --> 2018.8.24-py35_1001 conda-forge
#
# The following packages will be DOWNGRADED:
#
#     openssl:         1.0.2s-h7b6447c_0             --> 1.0.2r-h14c3975_0   conda-forge
#
#
# Downloading and Extracting Packages
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# certifi-2018.8.24    | 139 KB    | ##################################### | 100%
# altair-2.2.2         | 462 KB    | ##################################### | 100%
# openssl-1.0.2r       | 3.1 MB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# branca-0.3.1         | 25 KB     | ##################################### | 100%
# ca-certificates-2019 | 146 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#    Sydney City  2000
# 0       Ultimo  2007
# 1  Chippendale  2008
# 2      Pyrmont  2009
# 3  Surry Hills  2010
# 4  Kings Cross  2011

# %%
df_data_1.columns= ['Suburb', 'Postcode']
Sydney = df_data_1
Sydney.shape
# Out:
# (201, 2)

# %%
column_names = ['Suburb', 'Latitude','Longitude']

neighborhoods = pd.DataFrame(columns=column_names)

for row in Sydney.itertuples():
    Suburb = row[1]
    address = (row[1]+", Sydney")
    geolocator = Nominatim(user_agent="syd_explorer")
    location = geolocator.geocode(address)
    latitude = location.latitude
    longitude = location.longitude
    
    neighborhoods = neighborhoods.append({'Suburb':Suburb,
                                         'Latitude':latitude,
                                         'Longitude':longitude}, ignore_index=True)

# %%
neighborhoods.head()
# Out:
#         Suburb   Latitude   Longitude
# 0       Ultimo -33.879473  151.198435
# 1  Chippendale -33.886329  151.199821
# 2      Pyrmont -33.869214  151.192363
# 3  Surry Hills -33.884512  151.210030
# 4  Kings Cross -33.874601  151.222423

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# Your credentials:
# CLIENT_ID: 3EGISQY50CFC4HV3G2H4MQITJ2VE1QL4JAXF3CFM4VT4M4AE
# CLIENT_SECRET:DWHTOOJKO5QEYRSKSAVUERE4R541POOTILQGTBSUYWRAONI5

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        #print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

sydney_venues = getNearbyVenues(names=neighborhoods['Suburb'],
                                   latitudes=neighborhoods['Latitude'],
                                   longitudes=neighborhoods['Longitude']
                                  )

# %%
#Check function working above
sydney_venues.head()
# Out:
#   Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0       Ultimo             -33.879473              151.198435
# 1       Ultimo             -33.879473              151.198435
# 2       Ultimo             -33.879473              151.198435
# 3       Ultimo             -33.879473              151.198435
# 4       Ultimo             -33.879473              151.198435
#
#                                Venue  Venue Latitude  Venue Longitude  \
# 0  Museum of Applied Arts & Sciences      -33.878985       151.199555
# 1                    The Q on Harris      -33.879394       151.199455
# 2          Ian Thorpe Aquatic Centre      -33.877254       151.198805
# 3                  Powerhouse Museum      -33.878592       151.199512
# 4            Edition Coffee Roasters      -33.878485       151.201190
#
#    Venue Category
# 0          Museum
# 1     Coffee Shop
# 2            Pool
# 3  Science Museum
# 4            Café

# %%
# one hot encoding
sydney_onehot = pd.get_dummies(sydney_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
sydney_onehot['Neighborhood'] = sydney_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [sydney_onehot.columns[-1]] + list(sydney_onehot.columns[:-1])
sydney_onehot = sydney_onehot[fixed_columns]

sydney_grouped = sydney_onehot.groupby('Neighborhood').mean().reset_index()

num_top_venues = 5


def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = sydney_grouped['Neighborhood']

for ind in np.arange(sydney_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(sydney_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#   Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 0   Alexandria                  Café      Basketball Court
# 1    Annandale                  Café         Grocery Store
# 2    Arncliffe         Grocery Store              Platform
# 3     Artarmon                  Café   Japanese Restaurant
# 4     Ashfield    Chinese Restaurant   Japanese Restaurant
#
#        3rd Most Common Venue      4th Most Common Venue 5th Most Common Venue  \
# 0  Middle Eastern Restaurant         Italian Restaurant                   Bar
# 1      Australian Restaurant        Fried Chicken Joint     Fish & Chips Shop
# 2               Dessert Shop  Middle Eastern Restaurant              Pharmacy
# 3                       Park            Thai Restaurant     Korean Restaurant
# 4        Shanghai Restaurant          Electronics Store   Dumpling Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0             Wine Shop           Flower Shop     Fish & Chips Shop
# 1          Liquor Store        Farmers Market                   Pub
# 2          Intersection          Outlet Store                  Park
# 3           Coffee Shop      Sushi Restaurant      Ramen Restaurant
# 4          Liquor Store            Restaurant           Supermarket
#
#   9th Most Common Venue 10th Most Common Venue
# 0           Fish Market            Flea Market
# 1                   Bar                 Bakery
# 2           Fish Market   Fast Food Restaurant
# 3         Grocery Store                 Bakery
# 4     Korean Restaurant       Malay Restaurant

# %%
# set number of clusters
kclusters = 4

sydney_grouped_clustering = sydney_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(sydney_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10] 

# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

sydney_merged = neighborhoods

sydney_merged.rename(columns={'Suburb':'Neighborhood'},inplace=True)


sydney_merged = sydney_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
 
sydney_merged.head()
# Out:
#   Neighborhood   Latitude   Longitude  Cluster Labels 1st Most Common Venue  \
# 0       Ultimo -33.879473  151.198435             1.0                  Café
# 1  Chippendale -33.886329  151.199821             1.0                  Café
# 2      Pyrmont -33.869214  151.192363             0.0                   Bar
# 3  Surry Hills -33.884512  151.210030             1.0                  Café
# 4  Kings Cross -33.874601  151.222423             1.0                  Café
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0           Coffee Shop      Malay Restaurant                   Pub
# 1                   Bar                 Hotel           Art Gallery
# 2    Seafood Restaurant   Japanese Restaurant    Italian Restaurant
# 3           Coffee Shop                   Pub           Yoga Studio
# 4    Italian Restaurant     Indian Restaurant                Lounge
#
#    5th Most Common Venue 6th Most Common Venue    7th Most Common Venue  \
# 0       Asian Restaurant               Theater                     Pool
# 1            Yoga Studio              Wine Bar         Malay Restaurant
# 2                   Café                   Pub              Fish Market
# 3    Japanese Restaurant          Cocktail Bar         Ramen Restaurant
# 4  Australian Restaurant             Juice Bar  Fruit & Vegetable Store
#
#   8th Most Common Venue  9th Most Common Venue 10th Most Common Venue
# 0   Dumpling Restaurant  Australian Restaurant                 Lounge
# 1   Fried Chicken Joint    Dumpling Restaurant           Dessert Shop
# 2           Coffee Shop             Restaurant       Malay Restaurant
# 3        Sandwich Place     Mexican Restaurant         Breakfast Spot
# 4             Nightclub     Chinese Restaurant    Rental Car Location

# %%
sydney_merged.dropna(axis=0,how='any',inplace=True)
#sydney_merged['Cluster Labels', astype=int, inplace=True]
interim = sydney_merged['Cluster Labels']
interim = interim.astype(int)

sydney_merged[['Cluster Labels']] = interim
sydney_merged.head()
# Out:
#   Neighborhood   Latitude   Longitude  Cluster Labels 1st Most Common Venue  \
# 0       Ultimo -33.879473  151.198435               1                  Café
# 1  Chippendale -33.886329  151.199821               1                  Café
# 2      Pyrmont -33.869214  151.192363               0                   Bar
# 3  Surry Hills -33.884512  151.210030               1                  Café
# 4  Kings Cross -33.874601  151.222423               1                  Café
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0           Coffee Shop      Malay Restaurant                   Pub
# 1                   Bar                 Hotel           Art Gallery
# 2    Seafood Restaurant   Japanese Restaurant    Italian Restaurant
# 3           Coffee Shop                   Pub           Yoga Studio
# 4    Italian Restaurant     Indian Restaurant                Lounge
#
#    5th Most Common Venue 6th Most Common Venue    7th Most Common Venue  \
# 0       Asian Restaurant               Theater                     Pool
# 1            Yoga Studio              Wine Bar         Malay Restaurant
# 2                   Café                   Pub              Fish Market
# 3    Japanese Restaurant          Cocktail Bar         Ramen Restaurant
# 4  Australian Restaurant             Juice Bar  Fruit & Vegetable Store
#
#   8th Most Common Venue  9th Most Common Venue 10th Most Common Venue
# 0   Dumpling Restaurant  Australian Restaurant                 Lounge
# 1   Fried Chicken Joint    Dumpling Restaurant           Dessert Shop
# 2           Coffee Shop             Restaurant       Malay Restaurant
# 3        Sandwich Place     Mexican Restaurant         Breakfast Spot
# 4             Nightclub     Chinese Restaurant    Rental Car Location

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(sydney_merged['Latitude'], sydney_merged['Longitude'], sydney_merged['Neighborhood'], sydney_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
sydney_merged.loc[sydney_merged['Cluster Labels'] == 0, sydney_merged.columns[[0] + list(range(4, sydney_merged.shape[1]))]]
# Out:
#           Neighborhood      1st Most Common Venue      2nd Most Common Venue  \
# 2              Pyrmont                        Bar         Seafood Restaurant
# 10              Mascot            Thai Restaurant                     Bakery
# 12      Bondi Junction                       Café               Burger Joint
# 16               Bondi      Australian Restaurant                       Park
# 17           Edgecliff                Supermarket        Japanese Restaurant
# 22           Kingsford      Indonesian Restaurant         Chinese Restaurant
# 23          Kensington         Chinese Restaurant      Indonesian Restaurant
# 25            Pagewood           Asian Restaurant                       Park
# 32             Newtown                        Bar               Cocktail Bar
# 34           St Peters                    Brewery                        Pub
# 35          Haberfield         Italian Restaurant                Pizza Place
# 36           Five Dock           Sushi Restaurant                Pizza Place
# 46          Crows Nest        Japanese Restaurant                       Café
# 51           Lindfield                       Park                Golf Course
# 53              Gordon                Coffee Shop            Thai Restaurant
# 54              Pymble                Pizza Place                       Park
# 55          Turramurra                     Bakery                Pizza Place
# 56             St Ives             Breakfast Spot                        Pub
# 57           Wahroonga                       Café            Thai Restaurant
# 59         Mount Colah               Liquor Store                Pizza Place
# 60    Mount Kuring-gai                     Bakery             Scenic Lookout
# 65         Forestville                Pizza Place                Supermarket
# 68            Cremorne        Japanese Restaurant                       Café
# 69            Seaforth       Gym / Fitness Center         Falafel Restaurant
# 73            Collaroy                Coffee Shop     Furniture / Home Store
# 75           Brookvale                        Gym                    Brewery
# 76           Narrabeen                Pizza Place                       Lake
# 79             Bayview       Gym / Fitness Center         Falafel Restaurant
# 80             Newport                Pizza Place         Italian Restaurant
# 83         Gladesville            Thai Restaurant                       Café
# 84                Ryde        Fried Chicken Joint                       Café
# 86          Meadowbank                       Park                Pizza Place
# 87           Ermington                 Print Shop               Liquor Store
# 88           Rydalmere  Middle Eastern Restaurant                Bus Station
# 89             Telopea                    Library              Grocery Store
# 90         Carlingford                Coffee Shop                        Gym
# 92       Pennant Hills                       Café            Thai Restaurant
# 93              Epping                 Playground                        Gym
# 96         Cherrybrook              Metro Station                  Wine Shop
# 99      Sydney Markets                Coffee Shop       Fast Food Restaurant
# 101           Ashfield         Chinese Restaurant        Japanese Restaurant
# 102            Croydon                 Playground               Soccer Field
# 103       Croydon Park                Gas Station   Mediterranean Restaurant
# 104            Burwood         Chinese Restaurant                Coffee Shop
# 106            Enfield                Pizza Place                       Park
# 109           Homebush                Bus Station                       Park
# 111          Granville               Dessert Shop  Middle Eastern Restaurant
# 112       Regents Park                Pizza Place      Vietnamese Restaurant
# 113             Auburn                       Café                Supermarket
# 114     Wentworthville                   Platform                Pizza Place
# 117          Blacktown                    Theater               Concert Hall
# 118         Parramatta            Thai Restaurant               Burger Joint
# 119        North Rocks       Other Great Outdoors                  Wine Shop
# 122        Castle Hill                       Café           Department Store
# 123         Kellyville                   Bus Stop        Rental Car Location
# 126              Dural       Gym / Fitness Center         Italian Restaurant
# 128         Merrylands       Fast Food Restaurant                Pizza Place
# 129            Yennora                   Platform              Train Station
# 130       Chester Hill                       Café            Thai Restaurant
# 131          Villawood                   Platform              Train Station
# 132  Smithfield/W.Park       Fast Food Restaurant             Sandwich Place
# 133          Fairfield           Asian Restaurant                   Platform
# 134           Lansvale                 Food Truck       Fast Food Restaurant
# 136        Hoxton Park         Italian Restaurant                       Park
# 137      St Johns Park                 Playground              Event Service
# 141         Canterbury                Supermarket                   Platform
# 142            Campsie              Grocery Store                        Gym
# 143            Lakemba                Supermarket  Middle Eastern Restaurant
# 144          Punchbowl                Pizza Place  Middle Eastern Restaurant
# 145       Georges Hall                   Pharmacy                  Wine Shop
# 146            Yagoona               Gourmet Shop                  Wine Shop
# 150          Arncliffe              Grocery Store                   Platform
# 152             Bexley    Fruit & Vegetable Store          Convenience Store
# 157            Revesby               Home Service          Other Repair Shop
# 158         East Hills                   Platform                        Pub
# 159           Milperra              Deli / Bodega         Chinese Restaurant
# 160           Rockdale                Coffee Shop                   Pharmacy
# 162            Carlton                   Platform        Japanese Restaurant
# 164         Hurstville           Asian Restaurant             Cricket Ground
# 165         Blakehurst                       Park        Sporting Goods Shop
# 167           Mortdale                     Bakery               Home Service
# 168           Sylvania                Pizza Place         Chinese Restaurant
# 169         Oyster Bay                        Spa                       Park
# 172            Miranda           Department Store       Fast Food Restaurant
# 175            Kurnell                Sports Club      Outdoors & Recreation
# 176         Sutherland                       Café          Indian Restaurant
# 177          Heathcote                        Pub       Fast Food Restaurant
# 178              Menai       Fast Food Restaurant           Sushi Restaurant
# 180          Ingleburn     Furniture / Home Store    Fruit & Vegetable Store
# 181              Minto       Fast Food Restaurant                     Bakery
# 182           Narellan       Fast Food Restaurant                Pizza Place
# 184             Mulgoa       Fast Food Restaurant            Thai Restaurant
# 185          Kingswood       Fast Food Restaurant          Indian Restaurant
# 193       Erskine Park               Burger Joint                       Park
# 194           St Marys       Fast Food Restaurant               Liquor Store
# 195        Glendenning               Dance Studio                        Gym
# 197         Riverstone                        Pub                        Bar
# 198         Rooty Hill              Grocery Store                   Platform
# 199            Parklea              Historic Site                  Wine Shop
# 200        Minchinbury              Shopping Mall                Supermarket
#
#          3rd Most Common Venue      4th Most Common Venue  \
# 2          Japanese Restaurant         Italian Restaurant
# 10                        Café  Middle Eastern Restaurant
# 12          Mexican Restaurant           Sushi Restaurant
# 16             Thai Restaurant                       Café
# 17              Tennis Stadium                     Bakery
# 22            Malay Restaurant           Asian Restaurant
# 23                Burger Joint          Convenience Store
# 25                   Wine Shop             Farmers Market
# 32              Ice Cream Shop                       Café
# 34           Recreation Center                 Steakhouse
# 35                      Bakery        Japanese Restaurant
# 36               Grocery Store          Convenience Store
# 46           Indian Restaurant               Cocktail Bar
# 51                   Wine Shop         Falafel Restaurant
# 53                    Platform                        Gym
# 54                        Café                        Gym
# 55                Liquor Store                   Pharmacy
# 56                       Trail                       Park
# 57                 Coffee Shop          Indian Restaurant
# 59               Train Station       Fast Food Restaurant
# 60               Train Station         Seafood Restaurant
# 65                      Bakery                 Sports Bar
# 68                Cocktail Bar           Sushi Restaurant
# 69         Fried Chicken Joint          French Restaurant
# 73                    Pie Shop      Australian Restaurant
# 75                         Pub                Pizza Place
# 76       Australian Restaurant            Thai Restaurant
# 79         Fried Chicken Joint          French Restaurant
# 80                 Coffee Shop          Convenience Store
# 83                 Pizza Place                Supermarket
# 84           Electronics Store           Cuban Restaurant
# 86               Grocery Store              Train Station
# 87                Home Service                Flower Shop
# 88                Climbing Gym                Supermarket
# 89               Train Station                     Bakery
# 90                Noodle House                 Food Court
# 92           Indian Restaurant                        Gym
# 93                        Park    Health & Beauty Service
# 96              Farmers Market        Fried Chicken Joint
# 99             Harbor / Marina                  Multiplex
# 101        Shanghai Restaurant          Electronics Store
# 102          Convenience Store                       Park
# 103                Pizza Place             Sandwich Place
# 104               Noodle House                       Café
# 106          Fish & Chips Shop                Gas Station
# 109                  Wine Shop             Farmers Market
# 111                Pizza Place                  Wine Shop
# 112         Athletics & Sports              Train Station
# 113         Turkish Restaurant              Grocery Store
# 114                       Café            Thai Restaurant
# 117               Cocktail Bar                       Park
# 118               Dessert Shop                       Café
# 119             Farmers Market        Fried Chicken Joint
# 122              Movie Theater       Fast Food Restaurant
# 123                Music Venue              Train Station
# 126               Concert Hall                     Garden
# 128              Shopping Mall              Big Box Store
# 129         Falafel Restaurant        Fried Chicken Joint
# 130             Farmers Market         Falafel Restaurant
# 131         Falafel Restaurant        Fried Chicken Joint
# 132                  Wine Shop             Farmers Market
# 133  South American Restaurant                Bus Station
# 134                  Wine Shop    Fruit & Vegetable Store
# 136                  Wine Shop         Falafel Restaurant
# 137                        Bar                     Bakery
# 141                       Café  Middle Eastern Restaurant
# 142               Liquor Store           Department Store
# 143         Italian Restaurant            Bubble Tea Shop
# 144       Pakistani Restaurant         Falafel Restaurant
# 145         Falafel Restaurant        Fried Chicken Joint
# 146             Farmers Market        Fried Chicken Joint
# 150               Dessert Shop  Middle Eastern Restaurant
# 152                       Park       Fast Food Restaurant
# 157         Italian Restaurant                Flea Market
# 158              Train Station         Falafel Restaurant
# 159          Food & Drink Shop                Golf Course
# 160             Sandwich Place                       Café
# 162                        Gym              Train Station
# 164                   Aquarium                  Wine Shop
# 165         Dim Sum Restaurant               Veterinarian
# 167                       Park                Flower Shop
# 168       Gym / Fitness Center               Dessert Shop
# 169                    Dog Run                     Bakery
# 172                  Juice Bar                       Café
# 175                  Wine Shop         Falafel Restaurant
# 176            Thai Restaurant              Grocery Store
# 177                Flower Shop              Train Station
# 178                Coffee Shop          Convenience Store
# 180        Fried Chicken Joint          French Restaurant
# 181          Convenience Store             Farmers Market
# 182          German Restaurant               Dessert Shop
# 184              Grocery Store                  Wine Shop
# 185              Train Station                Pizza Place
# 193                  Wine Shop             Farmers Market
# 194                       Pool              Shopping Mall
# 195                Auto Garage             Lingerie Store
# 197                Pizza Place              Shopping Mall
# 198               Burger Joint                       Café
# 199         Falafel Restaurant        Fried Chicken Joint
# 200                Pizza Place    Fruit & Vegetable Store
#
#        5th Most Common Venue   6th Most Common Venue  7th Most Common Venue  \
# 2                       Café                     Pub            Fish Market
# 10               Pizza Place              Playground  Indonesian Restaurant
# 12              Noodle House     Japanese Restaurant     Italian Restaurant
# 16               Pizza Place           Grocery Store          Deli / Bodega
# 17                       Gym                     Pub                   Café
# 22        Italian Restaurant         Thai Restaurant           Dessert Shop
# 23          Sushi Restaurant        Malay Restaurant                    Gym
# 25       Fried Chicken Joint       French Restaurant             Food Truck
# 32                    Bakery       Indian Restaurant   Fast Food Restaurant
# 34               Coffee Shop  Furniture / Home Store   Fast Food Restaurant
# 35             Grocery Store             Coffee Shop                   Café
# 36               Coffee Shop      Chinese Restaurant   Fast Food Restaurant
# 46           Thai Restaurant          Ice Cream Shop      Korean Restaurant
# 51         French Restaurant              Food Truck           Food Service
# 53               Pizza Place            Noodle House                   Café
# 54               Coffee Shop           Train Station                    Pub
# 55                      Café           Grocery Store            Music Store
# 56      Fast Food Restaurant     Filipino Restaurant      Fish & Chips Shop
# 57             Train Station     Fried Chicken Joint     Chinese Restaurant
# 59        Falafel Restaurant       French Restaurant             Food Truck
# 60               Supermarket    Fast Food Restaurant    Filipino Restaurant
# 65                      Park         Thai Restaurant         Farmers Market
# 68         Korean Restaurant             Pizza Place      French Restaurant
# 69                Food Truck            Food Service             Food Court
# 73                      Park               Wine Shop   Fast Food Restaurant
# 75                 Pet Store            Liquor Store            Rugby Pitch
# 76                     Beach           Grocery Store       Sushi Restaurant
# 79                Food Truck            Food Service             Food Court
# 80                 Wine Shop      Chinese Restaurant         Farmers Market
# 83       Fried Chicken Joint        Greek Restaurant     Seafood Restaurant
# 84                       Gym               Multiplex             Steakhouse
# 86                  Pharmacy      Seafood Restaurant          Boat or Ferry
# 87                  Bus Stop             Flea Market   Fast Food Restaurant
# 88          Asian Restaurant         Thai Restaurant           Home Service
# 89               Fish Market          Farmers Market   Fast Food Restaurant
# 90            Sandwich Place           Big Box Store            Supermarket
# 92                  Bus Line             Bus Station         Sandwich Place
# 93         Fish & Chips Shop          Farmers Market   Fast Food Restaurant
# 96         French Restaurant              Food Truck           Food Service
# 99                     Hotel      Mexican Restaurant         Sandwich Place
# 101      Dumpling Restaurant            Liquor Store             Restaurant
# 102       Falafel Restaurant              Food Truck           Food Service
# 103       Chinese Restaurant           Grocery Store      Convenience Store
# 104         Asian Restaurant               Multiplex         Sandwich Place
# 106                     Café            Liquor Store      Electronics Store
# 109      Fried Chicken Joint       French Restaurant             Food Truck
# 111           Farmers Market       French Restaurant             Food Truck
# 112                Wine Shop             Flea Market   Fast Food Restaurant
# 113             Dessert Shop   Portuguese Restaurant   Fast Food Restaurant
# 114            Train Station           Grocery Store           Gourmet Shop
# 117              Opera House                   Plaza                   Café
# 118       Frozen Yogurt Shop     Japanese Restaurant     Mexican Restaurant
# 119        French Restaurant              Food Truck           Food Service
# 122               Food Court            Dessert Shop       Greek Restaurant
# 123              Flea Market    Fast Food Restaurant    Filipino Restaurant
# 126        French Restaurant              Food Truck           Food Service
# 128              Supermarket        Sushi Restaurant         Chocolate Shop
# 129        French Restaurant              Food Truck           Food Service
# 130     Fast Food Restaurant        Sushi Restaurant            Supermarket
# 131        French Restaurant              Food Truck           Food Service
# 132      Fried Chicken Joint       French Restaurant             Food Truck
# 133            Bowling Alley    Fast Food Restaurant     Chinese Restaurant
# 134      Fried Chicken Joint       French Restaurant           Food Service
# 136        French Restaurant              Food Truck           Food Service
# 137       Dim Sum Restaurant                   Diner    Fried Chicken Joint
# 141            Train Station            Camera Store      Korean Restaurant
# 142    Vietnamese Restaurant      Chinese Restaurant                  Plaza
# 143      Lebanese Restaurant           Grocery Store          Train Station
# 144        French Restaurant              Food Truck           Food Service
# 145        French Restaurant              Food Truck           Food Service
# 146        French Restaurant              Food Truck           Food Service
# 150                 Pharmacy            Intersection           Outlet Store
# 152           Farmers Market     Fried Chicken Joint      French Restaurant
# 157           Farmers Market    Fast Food Restaurant    Filipino Restaurant
# 158           Farmers Market    Fast Food Restaurant    Filipino Restaurant
# 159      Fried Chicken Joint                   Diner         Discount Store
# 160     Fast Food Restaurant             Supermarket            Bridal Shop
# 162                      Pub                 Theater           Dessert Shop
# 164      Filipino Restaurant       Fish & Chips Shop            Fish Market
# 165                Wine Shop     Filipino Restaurant      Fish & Chips Shop
# 167     Fast Food Restaurant     Filipino Restaurant      Fish & Chips Shop
# 168       Dim Sum Restaurant       French Restaurant             Food Truck
# 169       Photography Studio      Dim Sum Restaurant   Fast Food Restaurant
# 172           Sandwich Place       Electronics Store    Dumpling Restaurant
# 175        French Restaurant              Food Truck           Food Service
# 176                      Pub       Convenience Store           Burger Joint
# 177            Grocery Store       Fish & Chips Shop     Falafel Restaurant
# 178              Supermarket        Basketball Court                    Bar
# 180               Food Truck            Food Service             Food Court
# 181              Supermarket             Coffee Shop          Shopping Mall
# 182                Multiplex                    Café          Shopping Mall
# 184  Fruit & Vegetable Store     Fried Chicken Joint      French Restaurant
# 185        Convenience Store          Sandwich Place             Sports Bar
# 193      Fried Chicken Joint       French Restaurant             Food Truck
# 194              Supermarket             Coffee Shop            Flea Market
# 195      Fried Chicken Joint       French Restaurant             Food Truck
# 197        Convenience Store    Fast Food Restaurant                   Pool
# 198      Filipino Restaurant                  Bakery            Pizza Place
# 199        French Restaurant              Food Truck           Food Service
# 200        Fish & Chips Shop                    Park   Fast Food Restaurant
#
#      8th Most Common Venue      9th Most Common Venue 10th Most Common Venue
# 2              Coffee Shop                 Restaurant       Malay Restaurant
# 10                    Park         Italian Restaurant          Souvlaki Shop
# 12              Steakhouse                  Bookstore         Sandwich Place
# 16    Brazilian Restaurant  Middle Eastern Restaurant    American Restaurant
# 17   Australian Restaurant              Train Station         Sandwich Place
# 22             Coffee Shop         Frozen Yogurt Shop         Sandwich Place
# 23                     Pub               Liquor Store                   Park
# 25            Food Service                 Food Court      Food & Drink Shop
# 32        Sushi Restaurant                Beer Garden            Coffee Shop
# 34            Food Service                 Food Court      Food & Drink Shop
# 35               Wine Shop                Fish Market   Fast Food Restaurant
# 36                    Café         Seafood Restaurant               Pharmacy
# 46      Mexican Restaurant                Music Store           Noodle House
# 51              Food Court          Food & Drink Shop            Flower Shop
# 53    Fast Food Restaurant             Sandwich Place            Supermarket
# 54                  Bakery                 Distillery               Dive Bar
# 55      Persian Restaurant                 Playground      Convenience Store
# 56             Fish Market                Flea Market     Falafel Restaurant
# 57        Sushi Restaurant                     Bakery  Australian Restaurant
# 59            Food Service                 Food Court      Food & Drink Shop
# 60       Fish & Chips Shop                Fish Market            Flea Market
# 65    Fast Food Restaurant        Filipino Restaurant      Fish & Chips Shop
# 68                Wine Bar              Shopping Mall   Fast Food Restaurant
# 69       Food & Drink Shop                Flower Shop            Flea Market
# 73     Filipino Restaurant          Fish & Chips Shop            Fish Market
# 75             Supermarket         Italian Restaurant                   Café
# 76                  Bakery                       Café     Seafood Restaurant
# 79       Food & Drink Shop                Flower Shop            Flea Market
# 80       French Restaurant                 Food Truck           Food Service
# 83             Bus Station             Sandwich Place            Music Store
# 84             Supermarket           Sushi Restaurant   Cantonese Restaurant
# 86                    Café         Chinese Restaurant      Food & Drink Shop
# 87     Filipino Restaurant          Fish & Chips Shop            Fish Market
# 88              Food Court          Food & Drink Shop         Farmers Market
# 89     Filipino Restaurant          Fish & Chips Shop              Wine Shop
# 90               Wine Shop          Fish & Chips Shop            Fish Market
# 92    Fast Food Restaurant             Farmers Market       Sushi Restaurant
# 93     Filipino Restaurant                Fish Market          Event Service
# 96              Food Court          Food & Drink Shop            Flower Shop
# 99   Australian Restaurant        Filipino Restaurant      Fish & Chips Shop
# 101            Supermarket          Korean Restaurant       Malay Restaurant
# 102             Food Court          Food & Drink Shop            Flower Shop
# 103                   Park       Fast Food Restaurant    Filipino Restaurant
# 104   Fast Food Restaurant       Cantonese Restaurant             Hookah Bar
# 106        Thai Restaurant              Grocery Store     Chinese Restaurant
# 109           Food Service                 Food Court      Food & Drink Shop
# 111           Food Service                 Food Court      Food & Drink Shop
# 112    Filipino Restaurant          Fish & Chips Shop            Fish Market
# 113            Candy Store         Falafel Restaurant    Lebanese Restaurant
# 114      Fish & Chips Shop             Sandwich Place          Shopping Mall
# 117                   Tree                Music Venue  Performing Arts Venue
# 118       Malay Restaurant                      River             Restaurant
# 119             Food Court          Food & Drink Shop            Flower Shop
# 122          Shopping Mall                  Multiplex         Sandwich Place
# 123      Fish & Chips Shop                Fish Market              Wine Shop
# 126             Food Court         Falafel Restaurant      Food & Drink Shop
# 128           Burger Joint          Electronics Store  Portuguese Restaurant
# 129             Food Court          Food & Drink Shop            Flower Shop
# 130              Newsstand          Fish & Chips Shop          Train Station
# 131             Food Court          Food & Drink Shop            Flower Shop
# 132           Food Service                 Food Court      Food & Drink Shop
# 133      Electronics Store            Thai Restaurant               Pharmacy
# 134             Food Court          Food & Drink Shop            Flower Shop
# 136             Food Court          Food & Drink Shop            Flower Shop
# 137      French Restaurant                 Food Truck           Food Service
# 141                    Pub       Fast Food Restaurant    Japanese Restaurant
# 142   Fast Food Restaurant         Seafood Restaurant       Malay Restaurant
# 143            Pizza Place          Health Food Store      French Restaurant
# 144             Food Court          Food & Drink Shop            Flower Shop
# 145             Food Court          Food & Drink Shop            Flower Shop
# 146             Food Court          Food & Drink Shop            Flower Shop
# 150                   Park                Fish Market   Fast Food Restaurant
# 152             Food Truck               Food Service             Food Court
# 157      Fish & Chips Shop                Fish Market              Wine Shop
# 158      Fish & Chips Shop                Fish Market      Electronics Store
# 159      French Restaurant                 Food Truck           Food Service
# 160       Department Store                 Sports Bar           Liquor Store
# 162                  Diner         Falafel Restaurant             Food Truck
# 164            Flea Market                Flower Shop             Food Court
# 165            Fish Market                Flea Market            Flower Shop
# 167            Fish Market                Flea Market      Food & Drink Shop
# 168           Food Service                 Food Court      Food & Drink Shop
# 169    Fried Chicken Joint          French Restaurant             Food Truck
# 172              Multiplex                     Bakery           Burger Joint
# 175             Food Court          Food & Drink Shop            Flower Shop
# 176         Sandwich Place           Ramen Restaurant            Coffee Shop
# 177         Farmers Market        Filipino Restaurant              Wine Shop
# 178          Grocery Store                        Gym              Juice Bar
# 180      Food & Drink Shop                Flower Shop            Flea Market
# 181          Grocery Store          Food & Drink Shop            Flower Shop
# 182            Supermarket                Coffee Shop              Juice Bar
# 184             Food Truck               Food Service             Food Court
# 185         Baseball Field         Athletics & Sports               Platform
# 193           Food Service                 Food Court      Food & Drink Shop
# 194    Filipino Restaurant          Fish & Chips Shop            Fish Market
# 195           Food Service                 Food Court      Food & Drink Shop
# 197         Sandwich Place              Train Station              Wine Shop
# 198   Fast Food Restaurant                 Food Truck          Deli / Bodega
# 199             Food Court          Food & Drink Shop            Flower Shop
# 200    Filipino Restaurant                Fish Market            Flea Market

# %%
sydney_merged.loc[sydney_merged['Cluster Labels'] == 1, sydney_merged.columns[[0] + list(range(4, sydney_merged.shape[1]))]]
# Out:
#          Neighborhood  1st Most Common Venue          2nd Most Common Venue  \
# 0              Ultimo                   Café                    Coffee Shop
# 1         Chippendale                   Café                            Bar
# 3         Surry Hills                   Café                    Coffee Shop
# 4         Kings Cross                   Café             Italian Restaurant
# 5          Alexandria                   Café               Basketball Court
# 6             Redfern                   Café                            Bar
# 7            Waterloo                   Café              Korean Restaurant
# 8            Rosebery                   Café                         Bakery
# 9              Botany                   Café                 Ice Cream Shop
# 11         Paddington                   Café                            Bar
# 13      Bellevue Hill                   Café                          Hotel
# 14           Waverley                   Café                            Pub
# 15          Woollahra                   Café          Australian Restaurant
# 18         Double Bay                   Café            Japanese Restaurant
# 19           Rose Bay                   Café                Harbor / Marina
# 20           Vaucluse                   Café                Nature Preserve
# 21           Randwick                   Café                Thai Restaurant
# 24             Coogee                   Café                          Beach
# 26         Matraville                   Café                    Gas Station
# 27              Glebe                   Café                    Pizza Place
# 28          Annandale                   Café                  Grocery Store
# 29            Rozelle                   Café                            Pub
# 30         Leichhardt     Italian Restaurant                           Café
# 31            Balmain                   Café                            Bar
# 33       Erskineville                   Café                           Park
# 37          Drummoyne                   Café               Sushi Restaurant
# 38           Stanmore                   Café                            Pub
# 39          Petersham                   Café          Portuguese Restaurant
# 40         Camperdown                   Café                    Pizza Place
# 41       North Sydney                   Café                    Coffee Shop
# 42      Milsons Point                   Café                           Park
# 43           Cammeray                   Café                 Breakfast Spot
# 44        Northbridge                   Café                      Wine Shop
# 45           Artarmon                   Café            Japanese Restaurant
# 47          Lane Cove                   Café                    Pizza Place
# 48          Chatswood                   Café                    Coffee Shop
# 49         Willoughby                   Café                    Pizza Place
# 50          Roseville                   Café            Fried Chicken Joint
# 52            Killara                Theater                    Golf Course
# 58            Hornsby                   Café                            Gym
# 62       Terrey Hills            Flower Shop                           Café
# 63            Belrose          Grocery Store                   Soccer Field
# 64     Frenchs Forest            Bus Station                           Café
# 66             Mosman                   Café                         Bakery
# 67        Neutral Bay    Japanese Restaurant                           Café
# 70          Balgowlah    Japanese Restaurant                           Café
# 71              Manly                  Beach                           Café
# 72            Harbord                   Café                         Bakery
# 74            Dee Why                   Café                    Pizza Place
# 78          Mona Vale                   Café                           Park
# 81             Avalon                   Café                  Grocery Store
# 82       Hunters Hill                   Café                            Bar
# 85         North Ryde               Pharmacy                    Video Store
# 91           Beecroft                   Café                  Shopping Mall
# 94           Eastwood     Chinese Restaurant              Korean Restaurant
# 95   W. Pennant Hills                   Park                  Garden Center
# 97       Homebush Bay                   Café          Australian Restaurant
# 98        Silverwater                   Café              Electronics Store
# 100       Summer Hill                   Café                   Burger Joint
# 107           Concord                   Café             Italian Restaurant
# 108            Rhodes                   Café                           Park
# 110          Lidcombe                   Café              Korean Restaurant
# 115        Toongabbie      Indian Restaurant                           Café
# 116       Seven Hills                   Café              Electronics Store
# 121    Baulkham Hills                   Café                    Supermarket
# 135         Liverpool                   Café                    Coffee Shop
# 138          Chullora          Jewelry Store                           Café
# 139          Belfield            Pizza Place                           Café
# 140           Belmore                   Café      Middle Eastern Restaurant
# 147         Bankstown  Vietnamese Restaurant                           Café
# 148      Dulwich Hill                   Café                         Bakery
# 149      Marrickville  Vietnamese Restaurant                           Café
# 151          Earlwood             Playground                           Café
# 153        Kingsgrove                   Café                            Gym
# 154     Beverly Hills     Chinese Restaurant                           Café
# 155         Peakhurst     Falafel Restaurant                  Grocery Store
# 156           Padstow     Chinese Restaurant                       Bus Stop
# 161           Kogarah                   Café               Greek Restaurant
# 163        Sans Souci            Pizza Place                           Café
# 166         Penshurst                   Café                Thai Restaurant
# 170           Jannali                   Café                    Pizza Place
# 171             Gymea                   Café                   Burger Joint
# 173         Caringbah             Playground             Photography Studio
# 174          Cronulla                   Café                   Burger Joint
# 179      Campbelltown                  Motel  Paper / Office Supplies Store
# 183            Camden                   Café                            Bar
# 187           Penrith                   Café               Department Store
# 189          Richmond                   Café                    Pizza Place
# 191           Windsor                   Café                  Shopping Mall
# 192         Kurrajong                   Café                     Restaurant
#
#          3rd Most Common Venue          4th Most Common Venue  \
# 0             Malay Restaurant                            Pub
# 1                        Hotel                    Art Gallery
# 3                          Pub                    Yoga Studio
# 4            Indian Restaurant                         Lounge
# 5    Middle Eastern Restaurant             Italian Restaurant
# 6           Dim Sum Restaurant                       Dive Bar
# 7                  Pizza Place                         Bakery
# 8                 Burger Joint                 Cosmetics Shop
# 9              Badminton Court                   Liquor Store
# 11                 Pizza Place                     Restaurant
# 13                 Bus Station                   Liquor Store
# 14                 Pizza Place              Convenience Store
# 15          Italian Restaurant                           Park
# 18                Liquor Store                   Noodle House
# 19                        Park                    Beer Garden
# 20                       Beach                  Shopping Mall
# 21                         Pub           Fast Food Restaurant
# 24                       Hotel             Italian Restaurant
# 26                 Bus Station                      Wine Shop
# 27                      Bakery            Japanese Restaurant
# 28       Australian Restaurant            Fried Chicken Joint
# 29                 Bus Station  Vegetarian / Vegan Restaurant
# 30         Japanese Restaurant                            Pub
# 31                         Pub              Indian Restaurant
# 33                         Pub                         Bakery
# 37                         Pub            Lebanese Restaurant
# 38                  Restaurant                  Train Station
# 39                         Pub                    Yoga Studio
# 40       Australian Restaurant      Middle Eastern Restaurant
# 41                         Bar            Japanese Restaurant
# 42          Italian Restaurant                            Bar
# 43                   BBQ Joint                    Bus Station
# 44                        Park                 Farmers Market
# 45                        Park                Thai Restaurant
# 47                         Gym                         Bakery
# 48                  Food Court                            Gym
# 49        Gym / Fitness Center                    Bus Station
# 50                 Coffee Shop                      Wine Shop
# 52                        Café                  Train Station
# 58               Movie Theater              Korean Restaurant
# 62                         Pub                      Wine Shop
# 63                         Pub                           Café
# 64               Grocery Store               Sushi Restaurant
# 66                         Pub                   Burger Joint
# 67             Thai Restaurant                            Gym
# 70                        Park                   Liquor Store
# 71              Breakfast Spot          Australian Restaurant
# 72           Indian Restaurant               Sushi Restaurant
# 74               Shopping Mall                    Supermarket
# 78                 Supermarket           Fast Food Restaurant
# 81                 Coffee Shop                       Tea Room
# 82             Harbor / Marina                    Pizza Place
# 85                        Café         Thrift / Vintage Store
# 91          Chinese Restaurant                    Pizza Place
# 94                        Café            Japanese Restaurant
# 95                        Café                          Trail
# 97                        Park                      Wine Shop
# 98        Fast Food Restaurant                            Gym
# 100                Coffee Shop                    Pizza Place
# 107                Supermarket                    Golf Course
# 108           Asian Restaurant             Italian Restaurant
# 110                   Platform                       Bus Stop
# 115                        Pub                     Food Truck
# 116             Lighting Store                      Wine Shop
# 121                Pizza Place                       Pharmacy
# 135       Fast Food Restaurant                  Shopping Mall
# 138                  Wine Shop                 Farmers Market
# 139                       Park      Middle Eastern Restaurant
# 140                  BBQ Joint                    Pizza Place
# 147                     Buffet                     Sports Bar
# 148         Athletics & Sports       Mediterranean Restaurant
# 149                Pizza Place                      Juice Bar
# 151                   Pharmacy           Fast Food Restaurant
# 153               Liquor Store                    Supermarket
# 154        Japanese Restaurant                  Movie Theater
# 155               Home Service                           Café
# 156                       Café             Falafel Restaurant
# 161          Convenience Store                Thai Restaurant
# 163         Seafood Restaurant                    Supermarket
# 166       Fast Food Restaurant                    Gas Station
# 170            Thai Restaurant                         Bakery
# 171                Art Gallery                            Pub
# 173                       Café                          Trail
# 174             Ice Cream Shop                           Park
# 179                       Café           Fast Food Restaurant
# 183       Fast Food Restaurant          Australian Restaurant
# 187          Electronics Store                Thai Restaurant
# 189           Department Store                  Shopping Mall
# 191              Grocery Store             Seafood Restaurant
# 192                  Wine Shop             Falafel Restaurant
#
#       5th Most Common Venue  6th Most Common Venue    7th Most Common Venue  \
# 0          Asian Restaurant                Theater                     Pool
# 1               Yoga Studio               Wine Bar         Malay Restaurant
# 3       Japanese Restaurant           Cocktail Bar         Ramen Restaurant
# 4     Australian Restaurant              Juice Bar  Fruit & Vegetable Store
# 5                       Bar              Wine Shop              Flower Shop
# 6              Cocktail Bar       Ramen Restaurant                      Pub
# 7     Vietnamese Restaurant          Grocery Store                 Wine Bar
# 8    Furniture / Home Store          Souvlaki Shop             Food Service
# 9        Chinese Restaurant          Grocery Store                      Gym
# 11                      Pub               Boutique       Seafood Restaurant
# 13                Wine Shop   Fast Food Restaurant        French Restaurant
# 14               Restaurant     Belgian Restaurant    Vietnamese Restaurant
# 15                Wine Shop            Flea Market      Filipino Restaurant
# 18                    Hotel                 Bakery            Shopping Mall
# 19              Golf Course           Tennis Court          Thai Restaurant
# 20           History Museum       Sushi Restaurant                     Park
# 21              Supermarket                    Gym                Juice Bar
# 24            Burrito Place      Fish & Chips Shop         Sushi Restaurant
# 26     Fast Food Restaurant      French Restaurant               Food Truck
# 27                     Park                    Pub          Thai Restaurant
# 28        Fish & Chips Shop           Liquor Store           Farmers Market
# 29        Indian Restaurant      Electronics Store       Seafood Restaurant
# 30            Grocery Store               Pharmacy                Bookstore
# 31       Italian Restaurant            Pizza Place                     Park
# 33          Thai Restaurant            Pizza Place                  Theater
# 37    Vietnamese Restaurant         Cricket Ground                   Bakery
# 38                     Park      Fish & Chips Shop           Farmers Market
# 39              Pizza Place            Beer Garden       Chinese Restaurant
# 40               Sports Bar           Liquor Store                Gastropub
# 41                Juice Bar          Movie Theater         Greek Restaurant
# 42        Indian Restaurant             Theme Park      Japanese Restaurant
# 43                  Butcher             Sports Bar              Golf Course
# 44      Fried Chicken Joint      French Restaurant               Food Truck
# 45        Korean Restaurant            Coffee Shop         Sushi Restaurant
# 47                     Pool                    Pub          Organic Grocery
# 48         Sushi Restaurant             Food Truck            Shopping Mall
# 49      Japanese Restaurant                    Pub   Furniture / Home Store
# 50           Farmers Market      French Restaurant               Food Truck
# 52         Asian Restaurant     Falafel Restaurant     Fast Food Restaurant
# 58        Electronics Store      Indian Restaurant      Fried Chicken Joint
# 62       Falafel Restaurant      French Restaurant               Food Truck
# 63       Falafel Restaurant             Food Truck             Food Service
# 64           Sandwich Place         Farmers Market               Food Truck
# 66              Pizza Place          Grocery Store           Clothing Store
# 67             Tennis Court                   Park        Convenience Store
# 70                      Gym            Supermarket              Pizza Place
# 71                     Pool                  Trail           Scenic Lookout
# 72             Burger Joint           Cocktail Bar        Convenience Store
# 74              Coffee Shop      Fish & Chips Shop    General Entertainment
# 78                  Brewery                    Gym      Fried Chicken Joint
# 81                   Bakery             Restaurant           Sandwich Place
# 82                   Bakery          Shopping Mall            Grocery Store
# 85          Thai Restaurant              Wine Shop        Fish & Chips Shop
# 91                   Bakery           Liquor Store                     Park
# 94                      Pub          Grocery Store          Bubble Tea Shop
# 95                   Bakery           Food Service               Food Court
# 97              Flea Market    Filipino Restaurant        Fish & Chips Shop
# 98   Furniture / Home Store               Pharmacy               Hobby Shop
# 100                     Bar       Toy / Game Store                   Bakery
# 107    Fast Food Restaurant        Thai Restaurant                   Bakery
# 108   Australian Restaurant    Japanese Restaurant                      Gym
# 110          Sandwich Place  General Entertainment      Filipino Restaurant
# 115           Shopping Mall                 Bakery                      Gym
# 116    Fast Food Restaurant    Fried Chicken Joint        French Restaurant
# 121        Asian Restaurant          Shopping Mall     Fast Food Restaurant
# 135             Supermarket      Indian Restaurant                      Gym
# 138     Fried Chicken Joint      French Restaurant               Food Truck
# 139               BBQ Joint            Sports Club              Gas Station
# 140    Fast Food Restaurant     Chinese Restaurant        Food & Drink Shop
# 147             Pizza Place                    Bar        Convenience Store
# 148      Chinese Restaurant                 Bistro            Grocery Store
# 149      Seafood Restaurant         Sandwich Place            Deli / Bodega
# 151             Pizza Place           Home Service        Electronics Store
# 153         Thai Restaurant              Wine Shop              Fish Market
# 154    Gym / Fitness Center       Sushi Restaurant                      Pub
# 155       French Restaurant             Food Truck             Food Service
# 156          Farmers Market      French Restaurant               Food Truck
# 161                  Bakery     Italian Restaurant      Japanese Restaurant
# 163      Miscellaneous Shop      French Restaurant       Chinese Restaurant
# 166           Train Station          Grocery Store        Fish & Chips Shop
# 170     Japanese Restaurant               Pharmacy       Seafood Restaurant
# 171             Coffee Shop         Sandwich Place            Train Station
# 173             Flea Market   Fast Food Restaurant      Filipino Restaurant
# 174                     Bar            Music Venue                    Beach
# 179          Farmers Market    Fried Chicken Joint        French Restaurant
# 183                    Park          Grocery Store      American Restaurant
# 187   Performing Arts Venue            Coffee Shop           Sandwich Place
# 189                    Park            Supermarket           Discount Store
# 191             Flea Market    Fried Chicken Joint           Sandwich Place
# 192       French Restaurant             Food Truck             Food Service
#
#          8th Most Common Venue         9th Most Common Venue  \
# 0          Dumpling Restaurant         Australian Restaurant
# 1          Fried Chicken Joint           Dumpling Restaurant
# 3               Sandwich Place            Mexican Restaurant
# 4                    Nightclub            Chinese Restaurant
# 5            Fish & Chips Shop                   Fish Market
# 6                       Bakery                Gymnastics Gym
# 7           Italian Restaurant           Japanese Restaurant
# 8                  Coffee Shop         Australian Restaurant
# 9                       Bakery               Thai Restaurant
# 11                 Candy Store                          Road
# 13                  Food Truck                  Food Service
# 14           French Restaurant                         Diner
# 15           Fish & Chips Shop                   Fish Market
# 18            Malay Restaurant          Brazilian Restaurant
# 19                         Gym                   Coffee Shop
# 20                   Wine Shop             Fish & Chips Shop
# 21   Middle Eastern Restaurant            Mexican Restaurant
# 24           French Restaurant               Thai Restaurant
# 26                Food Service                    Food Court
# 27          Italian Restaurant                Farmers Market
# 28                         Pub                           Bar
# 29              Sandwich Place               Organic Grocery
# 30              Farmers Market                   Supermarket
# 31   Middle Eastern Restaurant            Frozen Yogurt Shop
# 33                    Sake Bar            Seafood Restaurant
# 37               Grocery Store                Sandwich Place
# 38        Fast Food Restaurant           Filipino Restaurant
# 39               Bowling Green            Falafel Restaurant
# 40                  Restaurant               Thai Restaurant
# 41                        Park                Sandwich Place
# 42                      Lounge                        Garden
# 43                         Gym               Thai Restaurant
# 44                Food Service                    Food Court
# 45            Ramen Restaurant                 Grocery Store
# 47               Shopping Mall                   Social Club
# 48       Performing Arts Venue              Malay Restaurant
# 49                 Gas Station              Malay Restaurant
# 50                Food Service                    Food Court
# 52         Filipino Restaurant             Fish & Chips Shop
# 58              Sandwich Place                 Bowling Alley
# 62                Food Service                    Food Court
# 63                  Food Court             Food & Drink Shop
# 64                Food Service                    Food Court
# 66                    Creperie            Italian Restaurant
# 67                         Bar                           Spa
# 70               Shopping Mall                   Fish Market
# 71                   Wine Shop                   Flea Market
# 72              Farmers Market                      Gym Pool
# 74         Fried Chicken Joint           Japanese Restaurant
# 78          Mexican Restaurant                Sandwich Place
# 81                       Beach                   Flea Market
# 82              Farmers Market          Fast Food Restaurant
# 85              Farmers Market          Fast Food Restaurant
# 91           Convenience Store                   Supermarket
# 94                Liquor Store                   Supermarket
# 95           Food & Drink Shop                   Flower Shop
# 97                 Fish Market                   Flower Shop
# 98              Sandwich Place             Fish & Chips Shop
# 100            Thai Restaurant                 Grocery Store
# 107                 Sports Bar           Japanese Restaurant
# 108         Dim Sum Restaurant                    Food Court
# 110       Fast Food Restaurant            Chinese Restaurant
# 115                        Bar                  Burger Joint
# 116                 Food Truck                  Food Service
# 121                        Gym                    Donut Shop
# 135           Department Store         Portuguese Restaurant
# 138               Food Service                    Food Court
# 139             Farmers Market                   Fish Market
# 140           Greek Restaurant               Thai Restaurant
# 147      Portuguese Restaurant            Chinese Restaurant
# 148                Coffee Shop                           Pub
# 149                     Lounge                  Liquor Store
# 151                 Food Court             Food & Drink Shop
# 153        Filipino Restaurant             Fish & Chips Shop
# 154          German Restaurant                    Restaurant
# 155                 Food Court             Food & Drink Shop
# 156               Food Service                    Food Court
# 161                Coffee Shop  General College & University
# 163               Liquor Store             Convenience Store
# 166             Farmers Market           Filipino Restaurant
# 170              Grocery Store             Indian Restaurant
# 171         Italian Restaurant             Convenience Store
# 173          Fish & Chips Shop                   Fish Market
# 174                   Tea Room                     Bookstore
# 179                 Food Truck                  Food Service
# 183               Food Service                    Food Court
# 187              Shopping Mall            Mexican Restaurant
# 189             Sandwich Place                 Train Station
# 191                Supermarket                    Restaurant
# 192                 Food Court             Food & Drink Shop
#
#           10th Most Common Venue
# 0                         Lounge
# 1                   Dessert Shop
# 3                 Breakfast Spot
# 4            Rental Car Location
# 5                    Flea Market
# 6            Japanese Restaurant
# 7                            Gym
# 8                      Wine Shop
# 9             Italian Restaurant
# 11                   Coffee Shop
# 13                    Food Court
# 14                           Spa
# 15                   Flower Shop
# 18                 Boat or Ferry
# 19         Australian Restaurant
# 20                   Fish Market
# 21                Sandwich Place
# 24                           Bar
# 26             Food & Drink Shop
# 27   Eastern European Restaurant
# 28                        Bakery
# 29                   Flea Market
# 30              Sushi Restaurant
# 31                Breakfast Spot
# 33     Middle Eastern Restaurant
# 37            Italian Restaurant
# 38                     Wine Shop
# 39                           Bar
# 40             Korean Restaurant
# 41         Vietnamese Restaurant
# 42             Food & Drink Shop
# 43                           Bar
# 44             Food & Drink Shop
# 45                        Bakery
# 47           Fried Chicken Joint
# 48                   Chaat Place
# 49               Thai Restaurant
# 50             Food & Drink Shop
# 52                   Fish Market
# 58            Chinese Restaurant
# 62             Food & Drink Shop
# 63                   Flower Shop
# 64             Food & Drink Shop
# 66           Fried Chicken Joint
# 67              Asian Restaurant
# 70             Fish & Chips Shop
# 71             Fish & Chips Shop
# 72                   Yoga Studio
# 74                 Bowling Alley
# 78                     Bookstore
# 81                   Fish Market
# 82           Filipino Restaurant
# 85           Filipino Restaurant
# 91             Fish & Chips Shop
# 94              Sushi Restaurant
# 95                Farmers Market
# 97                Farmers Market
# 98           Filipino Restaurant
# 100                          Pub
# 107            French Restaurant
# 108                 Food Service
# 110                       Bakery
# 115                     Platform
# 116                   Food Court
# 121                          Bar
# 135            Electronics Store
# 138            Food & Drink Shop
# 139          Filipino Restaurant
# 140         Gym / Fitness Center
# 147                    Multiplex
# 148             Sushi Restaurant
# 149              Thai Restaurant
# 151                  Flower Shop
# 153                  Flea Market
# 154              Thai Restaurant
# 155                  Flower Shop
# 156            Food & Drink Shop
# 161          Filipino Restaurant
# 163         Fast Food Restaurant
# 166                    Wine Shop
# 170            Health Food Store
# 171                  Pizza Place
# 173                  Flower Shop
# 174                Grocery Store
# 179                   Food Court
# 183            Food & Drink Shop
# 187          Fried Chicken Joint
# 189            Fish & Chips Shop
# 191                 Burger Joint
# 192                  Flower Shop

# %%
sydney_merged.loc[sydney_merged['Cluster Labels'] == 2, sydney_merged.columns[[0] + list(range(4, sydney_merged.shape[1]))]]
# Out:
#        Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 61   Berowra Waters    Seafood Restaurant         Boat or Ferry
# 120       Northmead    Seafood Restaurant         Bowling Green
# 196    Quakers Hill        Baseball Field             Wine Shop
#
#     3rd Most Common Venue  4th Most Common Venue 5th Most Common Venue  \
# 61        Harbor / Marina  Australian Restaurant     Fish & Chips Shop
# 120       Badminton Court         Baseball Field     French Restaurant
# 196        Farmers Market    Fried Chicken Joint     French Restaurant
#
#     6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 61            Fish Market           Flea Market           Flower Shop
# 120            Food Truck          Food Service            Food Court
# 196            Food Truck          Food Service            Food Court
#
#     9th Most Common Venue 10th Most Common Venue
# 61              Wine Shop   Fast Food Restaurant
# 120  Fast Food Restaurant      Food & Drink Shop
# 196     Food & Drink Shop            Flower Shop

# %%
sydney_merged.loc[sydney_merged['Cluster Labels'] == 3, sydney_merged.columns[[0] + list(range(4, sydney_merged.shape[1]))]]
# Out:
#     Neighborhood 1st Most Common Venue 2nd Most Common Venue  \
# 77    Warriewood      Business Service             Wine Shop
# 105  Strathfield      Business Service             Wine Shop
#
#     3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 77         Farmers Market   Fried Chicken Joint     French Restaurant
# 105        Farmers Market   Fried Chicken Joint     French Restaurant
#
#     6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 77             Food Truck          Food Service            Food Court
# 105            Food Truck          Food Service            Food Court
#
#     9th Most Common Venue 10th Most Common Venue
# 77      Food & Drink Shop            Flower Shop
# 105     Food & Drink Shop            Flower Shop

# %%
sydney_merged.loc[sydney_merged['Cluster Labels'] == 4, sydney_merged.columns[[0] + list(range(4, sydney_merged.shape[1]))]]
# Out:
# Empty DataFrame
# Columns: [Neighborhood, 1st Most Common Venue, 2nd Most Common Venue, 3rd Most Common Venue, 4th Most Common Venue, 5th Most Common Venue, 6th Most Common Venue, 7th Most Common Venue, 8th Most Common Venue, 9th Most Common Venue, 10th Most Common Venue]
# Index: []

# %%
sydney_merged.loc[sydney_merged['Cluster Labels'] == 5, sydney_merged.columns[[0] + list(range(4, sydney_merged.shape[1]))]]
# Out:
# Empty DataFrame
# Columns: [Neighborhood, 1st Most Common Venue, 2nd Most Common Venue, 3rd Most Common Venue, 4th Most Common Venue, 5th Most Common Venue, 6th Most Common Venue, 7th Most Common Venue, 8th Most Common Venue, 9th Most Common Venue, 10th Most Common Venue]
# Index: []

# %%
sydney_merged.loc[sydney_merged['Cluster Labels'] == 6, sydney_merged.columns[[0] + list(range(4, sydney_merged.shape[1]))]]
# Out:
# Empty DataFrame
# Columns: [Neighborhood, 1st Most Common Venue, 2nd Most Common Venue, 3rd Most Common Venue, 4th Most Common Venue, 5th Most Common Venue, 6th Most Common Venue, 7th Most Common Venue, 8th Most Common Venue, 9th Most Common Venue, 10th Most Common Venue]
# Index: []

# %%
sydney_merged.loc[sydney_merged['Cluster Labels'] == 7, sydney_merged.columns[[0] + list(range(4, sydney_merged.shape[1]))]]
# Out:
# Empty DataFrame
# Columns: [Neighborhood, 1st Most Common Venue, 2nd Most Common Venue, 3rd Most Common Venue, 4th Most Common Venue, 5th Most Common Venue, 6th Most Common Venue, 7th Most Common Venue, 8th Most Common Venue, 9th Most Common Venue, 10th Most Common Venue]
# Index: []

# %%
sydney_merged.loc[sydney_merged['Cluster Labels'] == 8, sydney_merged.columns[[0] + list(range(4, sydney_merged.shape[1]))]]
# Out:
# Empty DataFrame
# Columns: [Neighborhood, 1st Most Common Venue, 2nd Most Common Venue, 3rd Most Common Venue, 4th Most Common Venue, 5th Most Common Venue, 6th Most Common Venue, 7th Most Common Venue, 8th Most Common Venue, 9th Most Common Venue, 10th Most Common Venue]
# Index: []

# %%
sydney_merged.loc[sydney_merged['Cluster Labels'] == 9, sydney_merged.columns[[0] + list(range(4, sydney_merged.shape[1]))]]
# Out:
# Empty DataFrame
# Columns: [Neighborhood, 1st Most Common Venue, 2nd Most Common Venue, 3rd Most Common Venue, 4th Most Common Venue, 5th Most Common Venue, 6th Most Common Venue, 7th Most Common Venue, 8th Most Common Venue, 9th Most Common Venue, 10th Most Common Venue]
# Index: []

# %%
sydney_merged.loc[sydney_merged['Cluster Labels'] == 10, sydney_merged.columns[[0] + list(range(4, sydney_merged.shape[1]))]]
# Out:
# Empty DataFrame
# Columns: [Neighborhood, 1st Most Common Venue, 2nd Most Common Venue, 3rd Most Common Venue, 4th Most Common Venue, 5th Most Common Venue, 6th Most Common Venue, 7th Most Common Venue, 8th Most Common Venue, 9th Most Common Venue, 10th Most Common Venue]
# Index: []
